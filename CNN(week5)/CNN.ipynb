# %% [markdown]
# 1. CNN

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import NumericCNN as Model

# %%
cnn_model = Model.LetterModel()
(X_train, y_train), (X_val, y_val), (X_test, y_test) = cnn_model.load_data()
# Out:
# Train:  (79920, 28, 28, 1, 1)
# Valid:  (8880, 28, 28, 1, 1)
# Test:  (14800, 28, 28, 1, 1)

# %%
cnn_model.build_model()
cnn_model.train(X_train, y_train, X_val, y_val, X_test, y_test)
# Out:
# d:\New_Project\Python\HK1_2025-2026\venv311\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 625/625 - 16s - 26ms/step - accuracy: 0.7971 - loss: 0.6615 - val_accuracy: 0.8629 - val_loss: 0.4093
# Epoch 2/10
# 625/625 - 14s - 23ms/step - accuracy: 0.9017 - loss: 0.3011 - val_accuracy: 0.9007 - val_loss: 0.3027
# Epoch 3/10
# 625/625 - 19s - 30ms/step - accuracy: 0.9197 - loss: 0.2423 - val_accuracy: 0.9039 - val_loss: 0.2843
# Epoch 4/10
# 625/625 - 14s - 23ms/step - accuracy: 0.9301 - loss: 0.2084 - val_accuracy: 0.9108 - val_loss: 0.2670
# Epoch 5/10
# 625/625 - 16s - 26ms/step - accuracy: 0.9374 - loss: 0.1815 - val_accuracy: 0.9097 - val_loss: 0.2652
# Epoch 6/10
# ...

# %%
cnn_model.evaluate(X_test, y_test)
# Out:
# Test accuracy: 0.9200

# %%
cnn_model.plot_history()
