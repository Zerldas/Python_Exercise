# %%
from kMeans import KMeanAlg
from kNN import KNNAlg
from SVM import SVMAlg

# %% [markdown]
# ## 📘 Thuật toán K-Means

# %%
kmeans = KMeanAlg(cluster=3)
kmeans.load_data()
kmeans.fit(max_iter=5)
kmeans.animation()

# %% [markdown]
# ## 📗 Thuật toán KNN

# %%
knn = KNNAlg(k=5)
knn.load_data()
knn.set_test_point()
knn.animate()
knn.predict()

# %% [markdown]
# ## 📙 Thuật toán SVM

# %%
svm = SVMAlg(kernel='linear', c=1.0)
svm.load_data()
svm.train()
svm.draw_boundary()
